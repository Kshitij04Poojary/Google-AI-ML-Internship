# %% [markdown]
# <a href="https://colab.research.google.com/github/Kshitij04Poojary/Google-AI-ML-Internship/blob/main/Unit1/Hello_ML_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model=tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
model.compile(optimizer="sgd",loss="mean_squared_error")

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model.fit(xs,ys,epochs=300)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0048
# Epoch 2/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0047
# Epoch 3/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0046
# Epoch 4/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0045
# Epoch 5/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0044
# Epoch 6/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0044
# Epoch 7/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0043
# Epoch 8/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0042
# Epoch 9/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 10/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0040
# Epoch 11/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0039
# Epoch 12/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0038
# ...

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 107ms/step
# [[30.990889]]
